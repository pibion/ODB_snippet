# %%
import json_filter_utils_updated_final as abcd
import json
import re
def read_json_from_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
def save_json_to_file(data, filename):
    with open(filename, "w") as f:
        json.dump(data, f,separators=(',', ':'))

# %% [markdown]
# ## loading JSON structure and appling all the cuts

# %%
json1=read_json_from_file('../24250227_135126_start_original.json')
json_after_cut1 = abcd.filter_and_clean_json(json1)

# %%
save_json_to_file(json_after_cut1, "24250227_135126_Final_Size_Start_ODB.JSON")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("final_Start_ODB.png")
plt.figure(figsize=(12, 8))  #
plt.imshow(img)
plt.axis("off")  # hide axes
plt.show()
#just one detector was turn on!

# %% [markdown]
# ## loading JSON structure and appling all the cuts

# %%
json1_f_start = read_json_from_file('../Comparing_New/final_odbstart.json')
json_after_cut1 = abcd.filter_and_clean_json(json1_f_start)
save_json_to_file(json_after_cut1, "Final_Size_Start_ODB.JSON")

# %%
img = mpimg.imread("final_ODB_start_1.png")
plt.figure(figsize=(12, 8))  #
plt.imshow(img)
plt.axis("off")  # hide axes
plt.show()

# 2 detector on
